# %% [markdown]
# # Wine Quality
#
# ## Project Method

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy as sp
import sklearn

# %%
data = pd.read_csv(r'winequalityN.csv', header=None)
data
# Out:
#          0              1                 2            3               4   \
# 0      type  fixed acidity  volatile acidity  citric acid  residual sugar
# 1     white              7              0.27         0.36            20.7
# 2     white            6.3               0.3         0.34             1.6
# 3     white            8.1              0.28          0.4             6.9
# 4     white            7.2              0.23         0.32             8.5
# ...     ...            ...               ...          ...             ...
# 6493    red            6.2               0.6         0.08               2
# 6494    red            5.9              0.55          0.1             2.2
# 6495    red            6.3              0.51         0.13             2.3
# 6496    red            5.9             0.645         0.12               2
# 6497    red              6              0.31         0.47             3.6
#
#              5                    6                     7        8     9   \
# ...

# %%
data_np = data.to_numpy()

wine_type = data_np[:, 0]
fixed_acidity = data_np[:, 1]
volatile_acidity = data_np[:, 2]
citric_acid = data_np[:, 3]
residual_sugar = data_np[:, 4]
chlorides = data_np[:, 5]
free_sulfur_dioxide = data_np[:, 6]
total_sulfur_dioxide = data_np[:, 7]
density = data_np[:, 8]
pH = data_np[:, 9]
sulphates = data_np[:, 10]
alcohol = data_np[:, 11]
quality = data_np[:, 12]

print(fixed_acidity)
# Out:
# ['fixed acidity' '7' '6.3' ... '6.3' '5.9' '6']

# %%
for i in range(5):
    print(data_np[i])
# Out:
# ['type' 'fixed acidity' 'volatile acidity' 'citric acid' 'residual sugar'
#  'chlorides' 'free sulfur dioxide' 'total sulfur dioxide' 'density' 'pH'
#  'sulphates' 'alcohol' 'quality']
# ['white' '7' '0.27' '0.36' '20.7' '0.045' '45' '170' '1.001' '3' '0.45'
#  '8.8' '6']
# ['white' '6.3' '0.3' '0.34' '1.6' '0.049' '14' '132' '0.994' '3.3' '0.49'
#  '9.5' '6']
# ['white' '8.1' '0.28' '0.4' '6.9' '0.05' '30' '97' '0.9951' '3.26' '0.44'
#  '10.1' '6']
# ['white' '7.2' '0.23' '0.32' '8.5' '0.058' '47' '186' '0.9956' '3.19'
#  '0.4' '9.9' '6']

# %%
for i in range(10):
    print(wine_type[i] + " " + fixed_acidity[i])
# Out:
# type fixed acidity
# white 7
# white 6.3
# white 8.1
# white 7.2
# white 7.2
# white 8.1
# white 6.2
# white 7
# white 6.3

# %%
for i in range(100):
    if wine_type[i] == 'white':
        print(fixed_acidity[i])
# Out:
# 7
# 6.3
# 8.1
# 7.2
# 7.2
# 8.1
# 6.2
# 7
# 6.3
# 8.1
# 8.1
# 8.6
# 7.9
# 6.6
# 8.3
# 6.6
# 6.3
# nan
# 7.4
# 6.5
# 6.2
# 6.4
# 6.8
# 7.6
# 6.6
# 7
# 6.9
# 7
# 7.4
# 7.2
# 8.5
# 8.3
# 7.4
# 6.2
# 5.8
# 7.3
# 6.5
# 7
# 7.3
# 7.3
# 6.7
# 6.7
# 7
# 6.6
# 6.7
# 7.4
# 6.2
# 6.2
# 7
# 6.9
# 7.2
# 6.6
# 6.2
# 6.4
# 6.8
# 6.9
# 7.2
# 6
# 6.6
# 7.4
# 6.8
# 6
# 7
# 6.6
# 7.2
# 6.2
# 6.4
# 6.7
# 6.7
# 7.4
# 6.2
# 6.8
# 6
# 8.6
# 6.7
# 7.4
# 7.1
# 7
# 7.4
# 6.7
# 6.8
# 7.1
# 7.1
# 7.3
# 7.1
# 7.1
# 7.2
# 6.8
# 7.1
# 7.1
# 7.2
# 6.1
# 6.9
# 6.9
# 7.5
# 7.1
# 6
# 8.6
# 9.8

# %%
for i in range(5000):
    if wine_type[i] == 'red':
        print(fixed_acidity[i])
# Out:
# 7.4
# 7.8
# 7.8
# 11.2
# 7.4
# 7.4
# 7.9
# 7.3
# 7.8
# 7.5
# 6.7
# 7.5
# 5.6
# 7.8
# 8.9
# 8.9
# 8.5
# 8.1
# 7.4
# 7.9
# 8.9
# 7.6
# 7.9
# 8.5
# 6.9
# 6.3
# 7.6
# 7.9
# 7.1
# 7.8
# 6.7
# 6.9
# 8.3
# 6.9
# 5.2
# 7.8
# 7.8
# 8.1
# 5.7
# 7.3
# 7.3
# 8.8
# 7.5
# 8.1
# 6.8
# 4.6
# 7.7
# 8.7
# 6.4
# 5.6
# 8.8
# 6.6
# 6.6
# 8.6
# 7.6
# 7.7
# 10.2
# 7.5
# 7.8
# 7.3
# 8.8
# 7.7
# 7.5
# 7
# 7.2
# 7.2
# 7.5
# 6.6
# 9.3
# 8
# 7.7
# 7.7
# 7.7
# 8.3
# 9.7
# 8.8
# 8.8
# 6.8
# 6.7
# 8.3
# 6.2
# 7.8
# 7.4
# 7.3
# 6.3
# 6.9
# 8.6
# 7.7
# 9.3
# 7
# 7.9
# 8.6
# 8.6
# 7.7
# 5
# 4.7
# 6.8
# 7
# 7.6
# 8.1
# 8.3
